# %%
from src.data_loader import Data

Data().users
# Out:
#       user  preference  score
# 0      123          16      8
# 1      123          17      9
# 2      123          18      9
# 3      123          19      8
# 4      123          20     10
# ...    ...         ...    ...
# 5477   182           4     70
# 5478   182          68     50
# 5479   182          38     75
# 5480   182          42     80
# 5481   182          46     85
#
# [5482 rows x 3 columns]

# %%
Data().datos_personales
# Out:
#     user         name  age sex  occupation  children  y_c_age  o_c_age
# 0    123  Usuario_123   37   F           3         1        3        8
# 1    124  Usuario_124   42   M           8         1        3        8
# 2    125  Usuario_125   35   F          10         0        0        0
# 3    126  Usuario_126   50   M           4         0        0        0
# 4    127  Usuario_127   66   F          11         1       35       44
# 5    128  Usuario_128   79   F          11         1       50       56
# 6    129  Usuario_129   42   F           5         1        5       11
# 7    130  Usuario_130   37   F           3         1        1        6
# 8    131  Usuario_131   25   F           2         0        0        0
# 9    132  Usuario_132   52   M           2         1       20       32
# 10   133  Usuario_133   24   M           3         0        0        0
# 11   134  Usuario_134   41   F           5         1        4        7
# ...

# %%
from src.preprocess import merge_userdata_ocupacion
from src.assing_group import asignar_grupos


user_info = merge_userdata_ocupacion(Data().datos_personales, Data().ocupaciones)

# %%
user_info[user_info["user_id"] == 182].iloc[0]
# Out:
# user_id                           182
# name                         User_182
# age                                30
# sex                                 F
# id_occupation                       1
# children                            0
# young_children_age                  0
# older_children_age                  0
# occupation            Fuerzas armadas
# Name: 59, dtype: object

# %%
from src.assing_group import asignar_grupos
asignar_grupos(user_info[user_info["user_id"] == 182].iloc[0])
# Out:
# ['fuerzas armadas sin hijos', 'entre treinta y cuarenta sin hijos']

# %%
user_info = merge_userdata_ocupacion(Data().datos_personales,
                                     Data().ocupaciones)

row = user_info[user_info["user_id"] == 182].iloc[0]
row
# Out:
# user_id                           182
# name                         User_182
# age                                30
# sex                                 F
# id_occupation                       1
# children                            0
# young_children_age                  0
# older_children_age                  0
# occupation            Fuerzas armadas
# Name: 59, dtype: object

# %%
print('Demografico',dr.recommend(
    user_id=182,
    n=1,))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print('Demografico',dr.recommend(
#       2     user_id=182,
#       3     n=1,))
#
# File c:\Users\cpalo\OneDrive - Quanam\Maestria UPV\UPV_Master\S2_SR_Sistemas Recomendadores\ValenciaTourRecommender\src\base_recommender.py:34, in BaseRecommender.recommend(self, user_id, n)
#      29 def recommend(self, user_id, n=10):
#      30     """
#      31
#      32     Returns the top n items to recommend to the user_id (id, name, score)
#      33     """
# ---> 34     preferences = self.get_user_preferences(user_id)
#      35     items_visitados = self.get_items_visited(user_id)
#      36     relevant_items = self.get_relevant_items(preferences, items_visitados)
#
# ...

# %%
from src.demographic_recommender import DemographicRecommender
from src.content_recommender import ContentRecommender
from src.hybrid_recommender import HybridRecommender
from src.base_recommender import BaseRecommender
from src.evaluation import recommender_evaluation
from src.collaborative_recommender import CollaborativeRecommender

dr=DemographicRecommender()

print('Demografico',dr.recommend(
    user_id=183,
    n=1,))

cr=ContentRecommender()
print('Contenido',cr.recommend(
    user_id=183,
    n=1,))

cl  = CollaborativeRecommender()
print('Colaborativo',cl.recommend(
    user_id=183,
    n=1,))

hr  = HybridRecommender(dr = dr, cor = cl, cr = cr)
print('Hibrido',hr.recommend(
    user_id=183,
    n=1, checks = [0.3, 0.3, 0.4]))
# Out:
# Demografico [(np.int64(17393), 'Ciudad de las Ciencias', np.float64(10.712368421052632), 'fuerzas armadas sin hijos')]
# Contenido [(np.int64(17393), 'Ciudad de las Ciencias', np.float64(39.34736842105263), None)]
# Colaborativo [(np.int64(17440), 'Plaza Redonda', np.float64(10.0), np.int64(6))]
# Hibrido [(17393, 'Ciudad de las Ciencias', 15.017921052631579, None)]

# %%
db_users = Data().users
list(db_users.user.unique())
# Out:
# [np.int64(123),
#  np.int64(124),
#  np.int64(125),
#  np.int64(126),
#  np.int64(127),
#  np.int64(128),
#  np.int64(129),
#  np.int64(130),
#  np.int64(131),
#  np.int64(132),
#  np.int64(133),
#  np.int64(134),
#  np.int64(135),
#  np.int64(136),
#  np.int64(137),
#  np.int64(138),
#  np.int64(139),
#  np.int64(140),
#  np.int64(141),
#  np.int64(142),
#  np.int64(143),
#  np.int64(144),
#  np.int64(145),
#  np.int64(146),
#  np.int64(147),
#  np.int64(148),
#  np.int64(149),
#  np.int64(150),
#  np.int64(151),
#  np.int64(152),
#  np.int64(153),
#  np.int64(154),
#  np.int64(155),
#  np.int64(156),
#  np.int64(157),
#  np.int64(158),
#  np.int64(159),
#  np.int64(160),
#  np.int64(161),
#  np.int64(162),
#  np.int64(163),
#  np.int64(164),
#  np.int64(165),
#  np.int64(166),
#  np.int64(167),
#  np.int64(168),
#  np.int64(169),
#  np.int64(170),
#  np.int64(171),
#  np.int64(172),
#  np.int64(173),
#  np.int64(174),
#  np.int64(175),
#  np.int64(176),
#  np.int64(177),
# ...

# %%
if 176 not in db_users["user"].values:
    print("User 176 not in user_info")
else:   
    print("User 176 in user_info")
# Out:
# User 176 in user_info

# %%
lista_items
# Out:
# ['Casa de las Rocas-Museo del Corpus',
#  'Casa-Museo Benlliure',
#  'Casa-Museo Blasco Ibañez',
#  'Centro cultural Fundación Bancaja',
#  'Centro del Carmen-IVAM',
#  'Centro Julio Gonzalez-IVAM',
#  'El Oceanográfico',
#  'Museo de Bellas Artes de Valencia-San Pio V',
#  'Museo de Cerámica (Palacio Marqués de Dos Aguas)',
#  'Museo de historia de Valencia',
#  'Museo de la Catedral',
#  'Museo de la Ciudad',
#  'Museo de las Ciencias Príncipe Felipe',
#  'Museo de prehistoria y de las culturas de Valencia',
#  'Museo del Patriarca',
#  'Museo Fallero',
#  'Museo Taurino',
#  'Museo Valenciano de Historia Natural',
#  'Museo valenciano de la ilustración y la modernidad',
#  'Ayuntamiento de Valencia',
#  'Biblioteca',
#  'Biblioteca Municipal',
#  'Casa Museo Benlliure',
#  'Ciudad de las Ciencias',
#  'Edificio de Correos',
#  'Palacio de Benicarló (Cortes Valencianas)',
#  'El Almudín',
#  'Estación del Norte',
#  'Estadio de Mestalla',
# ...

# %%
import requests
import os
import urllib3
from src.data_loader import Data

api_key = open('api-key.txt').read()
lista_items = list(Data().items.name)

# Disable insecure request warning if you're aware of the risks
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)


url = "https://kgsearch.googleapis.com/v1/entities:search"
params = {
    'query': lista_items[6] + " España",
    'types': ['TouristAttraction', 'Thing', 'Place', 'EducationalOrganization', 'GovernmentOrganization', 'LocalBusiness',
              'Organization', 'Landmark'],
    'languages': "es",
    'limit': 1,
    'indent': True,
    'key': api_key,
}
print(params)

try:
    response = requests.get(url, params=params, verify=True)  # Enable verification for production
    response.raise_for_status()
    data = response.json()
    print(data)
except requests.exceptions.RequestException as e:
    print(f"Error making API request: {e}")

from IPython.display import display, Image
from urllib.request import urlopen
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from urllib.request import urlopen
from PIL import Image
import io

if len(data['itemListElement']) > 0:

    print(data['itemListElement'][0]['result']['name'])
    if 'image' in data['itemListElement'][0]['result']:
        response = urlopen(data['itemListElement'][0]['result']['image']['contentUrl'])
        image_data = response.read()
        image = Image.open(io.BytesIO(image_data))
        plt.imshow(image)
        plt.axis('off')  # Hide axes
        plt.show()
        print(data['itemListElement'][0]['result']['image']['contentUrl'])
    if 'url' in data['itemListElement'][0]['result']:
        print(data['itemListElement'][0]['result']['url'])
    if 'address' in data['itemListElement'][0]['result']:
        print(data['itemListElement'][0]['result']['address']['addressLocality'])
    if 'detailedDescription' in data['itemListElement'][0]['result']:
        print(data['itemListElement'][0]['result']['detailedDescription']['articleBody'])
# Out:
# {'query': 'El Oceanográfico España', 'types': ['TouristAttraction', 'Thing', 'Place', 'EducationalOrganization', 'GovernmentOrganization', 'LocalBusiness', 'Organization', 'Landmark'], 'languages': 'es', 'limit': 1, 'indent': True, 'key': 'AIzaSyDa5TMlmhgTTr7oIuWa1mXZC35qJZUTioc'}
# {'@context': {'goog': 'http://schema.googleapis.com/', 'kg': 'http://g.co/kg', '@vocab': 'http://schema.org/', 'detailedDescription': 'goog:detailedDescription', 'EntitySearchResult': 'goog:EntitySearchResult', 'resultScore': 'goog:resultScore'}, '@type': 'ItemList', 'itemListElement': []}

# %%
import requests
api_key = open('api-key-maps.txt').read()  # Your Google Maps API key

def get_place_details(place_name, api_key):
    # Search for tourist attractions in Valencia
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    params = {
        'query': lista_items[0] + " in Valencia, Spain",
        'key': api_key,
        'language': 'es',  
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        
        for place in data.get('results', []):
            nombre = place.get('name')
            direccion = place.get('formatted_address')
            if 'opening_hours' in place:
                opening_status = place['opening_hours'].get('open_now')
                if opening_status is True:
                    #print("Abierto ahora: Sí")
                    abierto = 'Sí'
                elif opening_status is False:
                    #print("Abierto ahora: No")
                    abierto = 'No'
            else:
                #print("Abierto ahora: Sin información")
                abierto = 'Sin información'
            valoracion = place.get('rating', 'N/A')
            n_valoraciones = place.get('user_ratings_total', 'N/A')
            return nombre, direccion, abierto, valoracion, n_valoraciones
            
    except requests.exceptions.RequestException as e:
        return f"Error making API request: {e}"
# Out:
# Name: Museo del Corpus - Casa de las Rocas
# Direccion: Calle Roteros 8, C/ de les Roques, 1, 46003 València, Valencia, España
# Abierto ahora: Sí
# Valoracion en Google Maps: 4.5 sobre 247 valoraciones
